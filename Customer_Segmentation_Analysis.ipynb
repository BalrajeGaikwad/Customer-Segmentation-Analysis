# %% [markdown]
# # Problem Statment
#
# **Customer Segmentation Analysis**
#
# Customer segmentation analysis is the problem of uncovering information about a firms customer base, based on their interactions with the business. In most cases this interactions is in terms of therir purchase behavior and patterns. We explore some of the ways in which this can ce used.
#
#
# You own the mall and want to understand the customers like who can be easily converge [Target customers] so that the senese can be given to markieting team and plan the strategy accordinglyy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/Mall_Customers.csv")

# %%
data.head(4)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77

# %%
data.shape
# Out:
# (200, 5)

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
import missingno as msno

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %% [markdown]
# # Data Visualization And EDA

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
plt.figure(figsize=(16,5))

plt.subplot(1,3,1)
sns.distplot(data['Age'])
plt.title("Distribution of Age")
plt.xlabel("Range of Age")
plt.ylabel("count")

plt.subplot(1,3,2)
sns.distplot(data['Annual Income (k$)'])
plt.title("Distribution of Annual Income")
plt.xlabel("Range of Income")
plt.ylabel("count")

plt.subplot(1,3,3)
sns.distplot(data['Age'])
plt.title("Spending Score (1-100)")
plt.xlabel("Range of Spending Score")
plt.ylabel("count")

plt.show()
# Out:
# <ipython-input-15-fd4c897535af>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# <ipython-input-15-fd4c897535af>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Annual Income (k$)'])
# <ipython-input-15-fd4c897535af>:16: UserWarning:
#
# ...

# %%
df = data.groupby('Gender').size()

df.plot(kind='pie', colors=['lightgreen', 'orange'], explode=[0, 0.05], labels=['Female', 'Male'], autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")  # Removing 'Gender' as it's redundant
plt.show()

# %%
data.hist(figsize=(16,10))
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
sns.pairplot(data, vars=['Spending Score (1-100)','Annual Income (k$)','Age'], hue='Gender')
plt.show()

# %%
### How Many Persons of Specific Age Group they are visit in mall

"""plt.figure(figsize=(16,8))
sns.countplot(data['Age'])
plt.title("Distribution of age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()"""
# Out:
# 'plt.figure(figsize=(16,8))\nsns.countplot(data[\'Age\'])\nplt.title("Distribution of age")\nplt.xlabel("Age")\nplt.ylabel("Count")\nplt.show()'

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Age', data=data, palette="viridis")  # Correcting how data is passed
plt.title("Distribution of Age", fontsize=14)
plt.xlabel("Age", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-23-793c9e61b625>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age', data=data, palette="viridis")  # Correcting how data is passed

# %%
### Annnual Income --- In which age or annual income people visit the mall

plt.figure(figsize=(12,6))
sns.countplot(x='Annual Income (k$)', data=data, palette="viridis")  # Correcting how data is passed
plt.title("Distribution of Annual Income (k$)", fontsize=14)
plt.xlabel("Annual Income (k$)", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-26-dbaf2a7a66c0>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Annual Income (k$)', data=data, palette="viridis")  # Correcting how data is passed

# %% [markdown]
# **Top 5 persons has annual income high they visit the mall**
#
# 54
#
# 78
#
# 48
#
# 60
#
# 62
#
# 63

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
### Speending Score

plt.figure(figsize=(12,6))
sns.countplot(x='Spending Score (1-100)', data=data, palette="viridis")  # Correcting how data is passed
plt.title("Distribution of Spending Score (1-100)", fontsize=14)
plt.xlabel("Spending Score (1-100)", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-27-b7f09a02babf>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Spending Score (1-100)', data=data, palette="viridis")  # Correcting how data is passed

# %% [markdown]
# **Spending Score **
#
# High 43 -- 55 --46 --73

# %%
# !pip install dabl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.5/558.5 kB 7.4 MB/s eta 0:00:00
# ...

# %%
import dabl

# %%
dabl.plot(data, target_col='Annual Income (k$)')
# Out:
# Target looks like regression
# /usr/local/lib/python3.11/dist-packages/dabl/plot/supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# [<Axes: title={'center': 'Target distribution'}, xlabel='Annual Income (k$)', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=1.98E-02'}, xlabel='Age', ylabel='Annual Income (k$)'>,
#          <Axes: title={'center': 'F=7.84E-03'}, xlabel='Spending Score (1-100)'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=6.83E-03'}, xlabel='Annual Income (k$)', ylabel='Gender'>]],
#        dtype=object)]

# %%
dabl.plot(data, target_col='Spending Score (1-100)')
# Out:
# Target looks like regression
# /usr/local/lib/python3.11/dist-packages/dabl/plot/supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# [<Axes: title={'center': 'Target distribution'}, xlabel='Spending Score (1...', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=-3.45E-01'}, xlabel='Age', ylabel='Spending Score (1...'>,
#          <Axes: title={'center': 'F=7.84E-03'}, xlabel='Annual Income (k$)'>]],
#        dtype=object),
#  array([[<Axes: title={'center': 'F=5.34E-02'}, xlabel='Spending Score (1-100)', ylabel='Gender'>]],
#        dtype=object)]

# %%
numeric_data = data.select_dtypes(include=['number'])  # Keep only numeric columns
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
#### find annual income of male or female and also spending score


for gender in ['Male', 'Female']:
    plt.scatter(x='Age', y='Annual Income (k$)',
                data=data[data['Gender'] == gender],
                label=gender, s=200, alpha=0.5)

plt.title("Annual Income vs Age")
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
plt.legend()
plt.show()

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
for gender in ['Male', 'Female']:
    plt.scatter(x='Annual Income (k$)', y='Spending Score (1-100)',
                data=data[data['Gender'] == gender],
                label=gender, s=200, alpha=0.5)

plt.title("Annual Income vs Spending Score (1-100)")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.legend()
plt.show()

# %% [markdown]
# # K Means Clustering

# %%
 data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
x=data.iloc[:,[3,4]].values

# %%
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans

# %%
"""
class sklearn.cluster.KMeans(n_clusters=8, *, init='k-means++', n_init='auto', max_iter=300, tol=0.0001,
verbose=0, random_state=None, copy_x=True, algorithm='lloyd')
"""
# Out:
# "\nclass sklearn.cluster.KMeans(n_clusters=8, *, init='k-means++', n_init='auto', max_iter=300, tol=0.0001, \nverbose=0, random_state=None, copy_x=True, algorithm='lloyd')\n"

# %%
k=[]

for i in range(1,11):
  kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
  kmeans.fit(x)
  k.append(kmeans.inertia_)

# %%
k
# Out:
# [269981.28000000014,
#  183653.3289473683,
#  106348.37306211119,
#  73880.64496247198,
#  44448.45544793369,
#  40825.16946386947,
#  33642.57922077922,
#  26686.837785187785,
#  24766.471609793436,
#  23103.122085983905]

# %%
plt.plot(range(1,11),k)
plt.show()

# %%
model=KMeans(n_clusters=5,init='k-means++',random_state=0)
y_kmeans=model.fit_predict(x)

# %%
plt.figure(1,figsize=(15,8))
plt.scatter(x[y_kmeans==0,0], x[y_kmeans==0,1], s=100, c='magenta', label='Cluster 1')
plt.scatter(x[y_kmeans==1,0], x[y_kmeans==1,1], s=100, c='blue', label='Cluster 2')
plt.scatter(x[y_kmeans==2,0], x[y_kmeans==2,1], s=100, c='cyan', label='Cluster 3')
plt.scatter(x[y_kmeans==3,0], x[y_kmeans==3,1], s=100, c='green', label='Cluster 4')
plt.scatter(x[y_kmeans==4,0], x[y_kmeans==4,1], s=100, c='red', label='Cluster 5')
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=200, c='yellow', label='Centroids')
plt.title('K Means Clustring Algorithm')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.legend()
plt.show()
